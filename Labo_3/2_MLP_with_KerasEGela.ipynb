# %% [markdown]
# # Lab 2: Sentiment Analysis with a Multi Layer Perceptron using Keras
#
# __Objective__: We'll repeat the experiments in Lab 1, but in this case we'll extend the model adding new layers. In addition we will review some of the regularization techniques seen in class. The objectives for the lab session are the following:
#
# - Learn adding layers in Keras.
# - Experiment using different number of hidden layers with different hidden units.
# - Experiment with regularization techniques such as early-stoping, reducing the model, weight regularization and drop-out.

# %% [markdown]
# ## 1. Loading the data
# We'll use the same data used in previous session. You need to follow the same steps specified in lab1.

# %%
# Mount Drive files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## for replicability of results
import numpy as np
import tensorflow as tf

np.random.seed(1)
tf.random.set_seed(2)

# %%
import re
import pandas as pd

# Let's do 2-way positive/negative classification instead of 5-way
def load_sst_data(path,
                  easy_label_map={0:0, 1:0, 2:None, 3:1, 4:1}):
    data = []
    with open(path) as f:
        for i, line in enumerate(f):
            example = {}
            example['label'] = easy_label_map[int(line[1])]
            if example['label'] is None:
                continue

            # Strip out the parse information and the phrase labels---we don't need those here
            text = re.sub(r'\s*(\(\d)|(\))\s*', '', line)
            example['text'] = text[1:]
            data.append(example)
    data = pd.DataFrame(data)
    return data

sst_home = '/content/drive/MyDrive/Colab Notebooks/TIA_Lab3/data/trees/'
training_set = load_sst_data(sst_home + 'train.txt')
dev_set = load_sst_data(sst_home + 'dev.txt')
test_set = load_sst_data(sst_home + 'test.txt')

print('Training size: {}'.format(len(training_set)))
print('Dev size: {}'.format(len(dev_set)))
print('Test size: {}'.format(len(test_set)))
# Out:
# Training size: 6920
# Dev size: 872
# Test size: 1821

# %% [markdown]
# ## 2. Preprocessing and vectorization

# %%
from tensorflow.keras.preprocessing import text
from sklearn.utils import shuffle

# Shuffle dataset
training_set = shuffle(training_set)
dev_set = shuffle(dev_set)

test_set = shuffle(test_set)

# Obtain text and label vectors, and tokenize the text
train_texts = training_set.text
train_labels = training_set.label

dev_texts = dev_set.text
dev_labels = dev_set.label

test_texts = test_set.text
test_labels = test_set.label

# Create a tokenize that takes the 1000 most common words
tokenizer = text.Tokenizer(num_words=1000)

# Build the word index (dictionary)
tokenizer.fit_on_texts(train_texts) # Create word index using only training part

# Vectorize texts into one-hot encoding representations
x_train = tokenizer.texts_to_matrix(train_texts, mode='binary')
x_dev = tokenizer.texts_to_matrix(dev_texts, mode='binary')
x_test = tokenizer.texts_to_matrix(test_texts, mode='binary')

y_train = train_labels
y_dev = dev_labels
y_test = test_labels

print('Shape of the training set (nb_examples, vector_size): {}'.format(x_train.shape))
print('Shape of the validation set (nb_examples, vector_size): {}'.format(x_dev.shape))
print('Shape of the test set (nb_examples, vector_size): {}'.format(x_test.shape))
# Out:
# Shape of the training set (nb_examples, vector_size): (6920, 1000)
# Shape of the validation set (nb_examples, vector_size): (872, 1000)
# Shape of the test set (nb_examples, vector_size): (1821, 1000)

# %% [markdown]
# ## 3. Building the model
# Based on previous code we'll extend the model to a Multi Layer Perceptron with one hidden units. For that we'll make use of a fully connected (```Dense```) layers with a ```relu``` activation. In this case the hidden layer will have 16 hidden units (feel free to explore different dimensionality of hidden units).
#
# Remenber that applying ```Dense``` layer with ```relu``` activation we are implementing the following tensor operation:
#
# ```
# output = relu(dot(W, input) + b)
# ```
# ### Exercise 1
# Answer the following questions:
# - What does having 16 hidden units mean? What the size of matrix ```W```?
#
# -----
#
# Increasing the number of hidden units we are allowing the network to learn more complex representations, but at the same time we are making the network more computationally expensive and may lead to overfit the training data.
#
# Regarding the architecture, there are three main decisions that we need to take:
# - The number of layers
# - The number of hidden units for each layers
# - Activation function of the layers

# %% [markdown]
# The code below implements a fully connected archicteture with only one intermediate layer and an output layer that predicts the sentiment of the input review.
#
# >>>>>>>![](http://ixa2.si.ehu.es/~jibloleo/uc3m_dl4nlp/img/Two_layers_NN.png)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

input_size = x_train[0].shape[0] ## vector length equals to vocabulary size.

# Define the model
model = Sequential()
model.add(Dense(units=16, activation='relu', input_shape=(input_size,)))
model.add(Dense(units=1, activation='sigmoid'))
# Note that we do not need to indicate the input shape for the sucessives layes

# Compile the model using a loss function and an optimizer.
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │        16,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,033 (62.63 KB)
#  Trainable params: 16,033 (62.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(x_train, y_train, epochs=100, batch_size=32, validation_data=(x_dev, y_dev), verbose=1)
# Out:
# Epoch 1/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5872 - loss: 0.6740 - val_accuracy: 0.7397 - val_loss: 0.5734
# Epoch 2/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7513 - loss: 0.5481 - val_accuracy: 0.7534 - val_loss: 0.5073
# Epoch 3/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7918 - loss: 0.4736 - val_accuracy: 0.7649 - val_loss: 0.4941
# Epoch 4/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8071 - loss: 0.4396 - val_accuracy: 0.7638 - val_loss: 0.4969
# Epoch 5/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8147 - loss: 0.4206 - val_accuracy: 0.7569 - val_loss: 0.5046
# Epoch 6/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8188 - loss: 0.4079 - val_accuracy: 0.7523 - val_loss: 0.5135
# Epoch 7/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8187 - loss: 0.3984 - val_accuracy: 0.7534 - val_loss: 0.5230
# Epoch 8/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8213 - loss: 0.3906 - val_accuracy: 0.7557 - val_loss: 0.5322
# Epoch 9/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8238 - loss: 0.3837 - val_accuracy: 0.7557 - val_loss: 0.5404
# Epoch 10/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8259 - loss: 0.3774 - val_accuracy: 0.7557 - val_loss: 0.5480
# Epoch 11/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8283 - loss: 0.3714 - val_accuracy: 0.7569 - val_loss: 0.5557
# Epoch 12/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8290 - loss: 0.3655 - val_accuracy: 0.7546 - val_loss: 0.5633
# Epoch 13/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8313 - loss: 0.3599 - val_accuracy: 0.7546 - val_loss: 0.5708
# Epoch 14/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8346 - loss: 0.3544 - val_accuracy: 0.7523 - val_loss: 0.5778
# Epoch 15/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8376 - loss: 0.3489 - val_accuracy: 0.7534 - val_loss: 0.5848
# Epoch 16/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8415 - loss: 0.3434 - val_accuracy: 0.7500 - val_loss: 0.5914
# Epoch 17/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8448 - loss: 0.3377 - val_accuracy: 0.7511 - val_loss: 0.5989
# Epoch 18/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8494 - loss: 0.3321 - val_accuracy: 0.7500 - val_loss: 0.6058
# Epoch 19/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8526 - loss: 0.3263 - val_accuracy: 0.7500 - val_loss: 0.6126
# Epoch 20/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8545 - loss: 0.3202 - val_accuracy: 0.7500 - val_loss: 0.6195
# Epoch 21/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8577 - loss: 0.3141 - val_accuracy: 0.7523 - val_loss: 0.6267
# Epoch 22/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8596 - loss: 0.3078 - val_accuracy: 0.7500 - val_loss: 0.6336
# Epoch 23/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8640 - loss: 0.3015 - val_accuracy: 0.7489 - val_loss: 0.6399
# Epoch 24/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8685 - loss: 0.2948 - val_accuracy: 0.7443 - val_loss: 0.6470
# Epoch 25/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8720 - loss: 0.2882 - val_accuracy: 0.7443 - val_loss: 0.6543
# Epoch 26/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8763 - loss: 0.2817 - val_accuracy: 0.7443 - val_loss: 0.6621
# Epoch 27/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8790 - loss: 0.2749 - val_accuracy: 0.7454 - val_loss: 0.6688
# Epoch 28/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8830 - loss: 0.2682 - val_accuracy: 0.7466 - val_loss: 0.6762
# Epoch 29/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8873 - loss: 0.2611 - val_accuracy: 0.7431 - val_loss: 0.6834
# Epoch 30/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8907 - loss: 0.2541 - val_accuracy: 0.7489 - val_loss: 0.6902
# Epoch 31/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8939 - loss: 0.2469 - val_accuracy: 0.7489 - val_loss: 0.6990
# Epoch 32/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8973 - loss: 0.2395 - val_accuracy: 0.7489 - val_loss: 0.7061
# Epoch 33/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9007 - loss: 0.2325 - val_accuracy: 0.7477 - val_loss: 0.7140
# Epoch 34/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9067 - loss: 0.2251 - val_accuracy: 0.7523 - val_loss: 0.7224
# Epoch 35/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9112 - loss: 0.2180 - val_accuracy: 0.7500 - val_loss: 0.7310
# Epoch 36/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9143 - loss: 0.2108 - val_accuracy: 0.7489 - val_loss: 0.7389
# Epoch 37/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9187 - loss: 0.2039 - val_accuracy: 0.7466 - val_loss: 0.7472
# Epoch 38/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9224 - loss: 0.1971 - val_accuracy: 0.7477 - val_loss: 0.7559
# Epoch 39/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9273 - loss: 0.1902 - val_accuracy: 0.7477 - val_loss: 0.7658
# Epoch 40/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9324 - loss: 0.1836 - val_accuracy: 0.7466 - val_loss: 0.7762
# Epoch 41/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9374 - loss: 0.1771 - val_accuracy: 0.7466 - val_loss: 0.7857
# Epoch 42/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9408 - loss: 0.1710 - val_accuracy: 0.7477 - val_loss: 0.7959
# Epoch 43/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9443 - loss: 0.1648 - val_accuracy: 0.7466 - val_loss: 0.8074
# Epoch 44/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9487 - loss: 0.1589 - val_accuracy: 0.7466 - val_loss: 0.8168
# Epoch 45/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9513 - loss: 0.1530 - val_accuracy: 0.7454 - val_loss: 0.8280
# Epoch 46/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9531 - loss: 0.1474 - val_accuracy: 0.7454 - val_loss: 0.8407
# Epoch 47/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9551 - loss: 0.1419 - val_accuracy: 0.7431 - val_loss: 0.8509
# Epoch 48/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9567 - loss: 0.1366 - val_accuracy: 0.7443 - val_loss: 0.8646
# Epoch 49/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9589 - loss: 0.1315 - val_accuracy: 0.7443 - val_loss: 0.8777
# Epoch 50/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9604 - loss: 0.1266 - val_accuracy: 0.7477 - val_loss: 0.8898
# Epoch 51/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9624 - loss: 0.1217 - val_accuracy: 0.7500 - val_loss: 0.9028
# Epoch 52/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9636 - loss: 0.1169 - val_accuracy: 0.7500 - val_loss: 0.9167
# Epoch 53/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9648 - loss: 0.1125 - val_accuracy: 0.7500 - val_loss: 0.9293
# Epoch 54/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9668 - loss: 0.1082 - val_accuracy: 0.7523 - val_loss: 0.9443
# Epoch 55/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9689 - loss: 0.1039 - val_accuracy: 0.7511 - val_loss: 0.9582
# Epoch 56/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9702 - loss: 0.0999 - val_accuracy: 0.7454 - val_loss: 0.9721
# Epoch 57/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9717 - loss: 0.0960 - val_accuracy: 0.7454 - val_loss: 0.9877
# Epoch 58/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9721 - loss: 0.0923 - val_accuracy: 0.7408 - val_loss: 1.0015
# Epoch 59/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9722 - loss: 0.0889 - val_accuracy: 0.7397 - val_loss: 1.0180
# Epoch 60/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9735 - loss: 0.0853 - val_accuracy: 0.7385 - val_loss: 1.0308
# Epoch 61/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9753 - loss: 0.0820 - val_accuracy: 0.7408 - val_loss: 1.0474
# Epoch 62/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9759 - loss: 0.0788 - val_accuracy: 0.7408 - val_loss: 1.0628
# Epoch 63/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9769 - loss: 0.0758 - val_accuracy: 0.7397 - val_loss: 1.0788
# Epoch 64/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9773 - loss: 0.0728 - val_accuracy: 0.7431 - val_loss: 1.0939
# Epoch 65/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9784 - loss: 0.0700 - val_accuracy: 0.7420 - val_loss: 1.1107
# Epoch 66/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9790 - loss: 0.0674 - val_accuracy: 0.7374 - val_loss: 1.1274
# Epoch 67/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9793 - loss: 0.0648 - val_accuracy: 0.7397 - val_loss: 1.1434
# Epoch 68/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9801 - loss: 0.0623 - val_accuracy: 0.7362 - val_loss: 1.1590
# Epoch 69/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9804 - loss: 0.0600 - val_accuracy: 0.7374 - val_loss: 1.1763
# Epoch 70/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9805 - loss: 0.0577 - val_accuracy: 0.7362 - val_loss: 1.1928
# Epoch 71/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9819 - loss: 0.0555 - val_accuracy: 0.7385 - val_loss: 1.2101
# Epoch 72/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9824 - loss: 0.0537 - val_accuracy: 0.7351 - val_loss: 1.2286
# Epoch 73/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9825 - loss: 0.0516 - val_accuracy: 0.7385 - val_loss: 1.2459
# Epoch 74/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9830 - loss: 0.0498 - val_accuracy: 0.7374 - val_loss: 1.2637
# Epoch 75/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9840 - loss: 0.0480 - val_accuracy: 0.7362 - val_loss: 1.2821
# Epoch 76/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9850 - loss: 0.0464 - val_accuracy: 0.7351 - val_loss: 1.2996
# Epoch 77/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9862 - loss: 0.0448 - val_accuracy: 0.7374 - val_loss: 1.3185
# Epoch 78/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9868 - loss: 0.0432 - val_accuracy: 0.7305 - val_loss: 1.3368
# Epoch 79/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9868 - loss: 0.0419 - val_accuracy: 0.7317 - val_loss: 1.3542
# Epoch 80/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9877 - loss: 0.0404 - val_accuracy: 0.7305 - val_loss: 1.3740
# Epoch 81/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9882 - loss: 0.0392 - val_accuracy: 0.7328 - val_loss: 1.3901
# Epoch 82/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9884 - loss: 0.0379 - val_accuracy: 0.7339 - val_loss: 1.4101
# Epoch 83/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9884 - loss: 0.0367 - val_accuracy: 0.7328 - val_loss: 1.4270
# Epoch 84/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9886 - loss: 0.0356 - val_accuracy: 0.7328 - val_loss: 1.4448
# Epoch 85/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9889 - loss: 0.0345 - val_accuracy: 0.7317 - val_loss: 1.4634
# Epoch 86/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9889 - loss: 0.0335 - val_accuracy: 0.7328 - val_loss: 1.4809
# Epoch 87/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9894 - loss: 0.0325 - val_accuracy: 0.7317 - val_loss: 1.4991
# Epoch 88/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9892 - loss: 0.0316 - val_accuracy: 0.7317 - val_loss: 1.5183
# Epoch 89/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9894 - loss: 0.0307 - val_accuracy: 0.7328 - val_loss: 1.5370
# Epoch 90/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9896 - loss: 0.0299 - val_accuracy: 0.7305 - val_loss: 1.5565
# Epoch 91/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9898 - loss: 0.0290 - val_accuracy: 0.7294 - val_loss: 1.5739
# Epoch 92/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9900 - loss: 0.0284 - val_accuracy: 0.7271 - val_loss: 1.5923
# Epoch 93/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9903 - loss: 0.0276 - val_accuracy: 0.7294 - val_loss: 1.6117
# Epoch 94/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9903 - loss: 0.0269 - val_accuracy: 0.7282 - val_loss: 1.6292
# Epoch 95/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9905 - loss: 0.0262 - val_accuracy: 0.7294 - val_loss: 1.6483
# Epoch 96/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9907 - loss: 0.0256 - val_accuracy: 0.7282 - val_loss: 1.6669
# Epoch 97/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9907 - loss: 0.0249 - val_accuracy: 0.7305 - val_loss: 1.6843
# Epoch 98/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9907 - loss: 0.0244 - val_accuracy: 0.7294 - val_loss: 1.7033
# Epoch 99/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9910 - loss: 0.0238 - val_accuracy: 0.7305 - val_loss: 1.7201
# Epoch 100/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9910 - loss: 0.0233 - val_accuracy: 0.7317 - val_loss: 1.7411

# %%
import matplotlib.pyplot as plt

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'dev'], loc='upper left')
plt.show()


# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'dev'], loc='upper left')
plt.show()

# %% [markdown]
# ### Exercise 2
# Plots shows that model ends up overfitting the training data. One way to prevent overfitting is to stop training once accuracy in the validation set starts decreasing.
# - Could you retrain the model from the scratch for only four epochs?
#
# - Optionally, Keras provides early stopping mechanism as callback object(https://keras.io/callbacks/#earlystopping) that could be used when fiting the model:
#
# ```
# from tensorflow.keras.callbacks import EarlyStopping
# ...
# early_stop = EarlyStopping(monitor='val_accuracy', patience=1)
# ...
# history_exercise = model.fit(x_train, y_train, epochs=100, batch_size=32, validation_data=(x_dev, y_dev), verbose=1, callbacks=[early_stop])
#
# ```

# %%
### TODO: copy the code above and adapt to complete the exercise
from tensorflow.keras.callbacks import EarlyStopping
model = Sequential()
model.add(Dense(units=16, activation='sigmoid', input_shape=(input_size,)))
model.add(Dense(units=1, activation='tanh'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
early_stop = EarlyStopping(monitor='val_accuracy', patience=1)
history_exer = model.fit(x_train, y_train, epochs=4, batch_size=8, validation_data=(x_dev, y_dev), verbose=1, callbacks=[early_stop])
score = model.evaluate(x_test, y_test, verbose=1)
print("Accuracy: ", score[1])
# Out:
# Epoch 1/4
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4797 - loss: 8.3869 - val_accuracy: 0.4908 - val_loss: 8.2069
# Epoch 2/4
# 865/865 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4797 - loss: 8.3869 - val_accuracy: 0.4908 - val_loss: 8.2069
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5082 - loss: 7.9269
# Accuracy:  0.5008237361907959

# %%
# summarize history for accuracy
plt.plot(history_exer.history['accuracy'])
plt.plot(history_exer.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'dev'], loc='upper left')
plt.show()


# summarize history for loss
plt.plot(history_exer.history['loss'])
plt.plot(history_exer.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'dev'], loc='upper left')
plt.show()

# %% [markdown]
# ---
# - Optionally you can try different activations (e.g ```tanh```, ```sigmoid```) instead of ```relu```.
# - Or try different loss function like mean_squared_error (```mse```).
#
# ---

# %% [markdown]
# ## 3.1 Adding new layers
# In this section we will extend the model by adding new fully connected layer. By adding new layers we are increasing the capacity of the model we are not reducing the overfitting, but for the moment  we do not care about this.
#
# ### Exercise 3
# - The code below defines a model with two hidden layers,  add a third intermediate layer with 16 hidden units and ```relu``` activation.

# %%
input_size = x_train[0].shape[0] ## vector length equals to vocabulary size.

# Define the model TODO: add a third intermediate layer
model = Sequential()
model.add(Dense(units=16, activation='relu', input_shape=(input_size,)))
model.add(Dense(units=16, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
# Note that we do not need to indicate the input shape for the sucessives layers
# Compile the model using a loss function and an optimizer.
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# Train the model
history = model.fit(x_train, y_train, epochs=20, batch_size=32, validation_data=(x_dev, y_dev), verbose=1)
history_orig = history

# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'dev'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 16)             │        16,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,305 (63.69 KB)
#  Trainable params: 16,305 (63.69 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5665 - loss: 0.6789 - val_accuracy: 0.7374 - val_loss: 0.5476
# Epoch 2/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7574 - loss: 0.5210 - val_accuracy: 0.7615 - val_loss: 0.4949
# Epoch 3/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7973 - loss: 0.4427 - val_accuracy: 0.7615 - val_loss: 0.5063
# Epoch 4/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8204 - loss: 0.4065 - val_accuracy: 0.7626 - val_loss: 0.5246
# Epoch 5/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8356 - loss: 0.3736 - val_accuracy: 0.7557 - val_loss: 0.5467
# Epoch 6/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8539 - loss: 0.3383 - val_accuracy: 0.7557 - val_loss: 0.5766
# Epoch 7/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8761 - loss: 0.3001 - val_accuracy: 0.7477 - val_loss: 0.6150
# Epoch 8/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8969 - loss: 0.2625 - val_accuracy: 0.7454 - val_loss: 0.6676
# Epoch 9/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9142 - loss: 0.2292 - val_accuracy: 0.7408 - val_loss: 0.7233
# Epoch 10/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9258 - loss: 0.1969 - val_accuracy: 0.7397 - val_loss: 0.7897
# Epoch 11/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9409 - loss: 0.1681 - val_accuracy: 0.7397 - val_loss: 0.8595
# Epoch 12/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9537 - loss: 0.1426 - val_accuracy: 0.7385 - val_loss: 0.9474
# Epoch 13/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9614 - loss: 0.1200 - val_accuracy: 0.7339 - val_loss: 1.0347
# Epoch 14/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9679 - loss: 0.1017 - val_accuracy: 0.7374 - val_loss: 1.1183
# Epoch 15/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9739 - loss: 0.0831 - val_accuracy: 0.7328 - val_loss: 1.2145
# Epoch 16/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9783 - loss: 0.0692 - val_accuracy: 0.7317 - val_loss: 1.2964
# Epoch 17/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9829 - loss: 0.0576 - val_accuracy: 0.7294 - val_loss: 1.3831
# Epoch 18/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9863 - loss: 0.0479 - val_accuracy: 0.7328 - val_loss: 1.4796
# Epoch 19/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9882 - loss: 0.0403 - val_accuracy: 0.7305 - val_loss: 1.5692
# Epoch 20/20
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9888 - loss: 0.0349 - val_accuracy: 0.7317 - val_loss: 1.6586

# %% [markdown]
# ## 4. Regularization techniques
#
# We will apply the following ones:
# - Reducing the network size
# - Adding weight regularization
# - Adding dropout
#
# ### 4.1 Reducing the network size
# One way to prevent overfitting is to reduce the size of the model. As we know the size of the model is measured with the number of parameters that we need to learn. Remenber that the number of parameters are determined by the number of layers and the number of units per layer.

# %% [markdown]
# ### Exercise 4
# Run the following cell of code and try to answer the following question:
# - Can you describe the relation of training and validation loss curves when traning with less parameters?

# %%
input_size = x_train[0].shape[0] ## vector length equals to vocabulary size.

# Define the model
model = Sequential()
model.add(Dense(units=4, activation='relu', input_shape=(input_size,)))
model.add(Dense(units=4, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
# Note that we do not need to indicate the input shape for the sucessives layes

# Compile the model using a loss function and an optimizer.
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# Train the model
history = model.fit(x_train, y_train, epochs=20, batch_size=32, validation_data=(x_dev, y_dev), verbose=0)

# summarize history for accuracy
plt.plot(history_orig.history['loss'])
plt.plot(history.history['loss'])

plt.plot(history_orig.history['val_loss'])
plt.plot(history.history['val_loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train: orig model', 'train: small model', 'dev: orig model', 'dev: small model'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 4)              │         4,004 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 4)              │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,029 (15.74 KB)
#  Trainable params: 4,029 (15.74 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# We can compare the loss of bigger model with a higher _capacity_. Note that a model with a higher number of parameters has more memorization capacity and consequently can show a poorer generalization with higher risk of overfitting to training data.
#
# ### Exercise 5
# Run the following cell of code and try to answer the following question:
# - Can you describe the relation of training and validation loss curves when traning with more parameters?

# %%
input_size = x_train[0].shape[0] ## vector length equals to vocabulary size.

# Define the model
model = Sequential()
model.add(Dense(units=512, activation='relu', input_shape=(input_size,)))
model.add(Dense(units=512, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
# Note that we do not need to indicate the input shape for the sucessives layes

# Compile the model using a loss function and an optimizer.
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# Train the model
history = model.fit(x_train, y_train, epochs=20, batch_size=32, validation_data=(x_dev, y_dev), verbose=0)

# summarize history for accuracy
plt.plot(history_orig.history['loss'])
plt.plot(history.history['loss'])

plt.plot(history_orig.history['val_loss'])
plt.plot(history.history['val_loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train: orig model', 'train: bigger model', 'dev: orig model', 'dev: bigger model'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 512)            │       512,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 775,681 (2.96 MB)
#  Trainable params: 775,681 (2.96 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# -----
#
# ### 4.2 Adding weight regularization
#
# Another common way to try avoiding overfitting is to put constraints on the complexity of a network by forcing its weights to only take small values, which makes the distribution of weight values more "regular". This is called _weight regularization_, and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# - __L1 regularization__, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# - __L2 regularization__, where the cost added is proportional to the square of the value of the weights coefficients.
#
# In Keras, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. In this case, we'll use the L2 norm to regularize the weights of the model.

# %%
from tensorflow.keras import regularizers

input_size = x_train[0].shape[0] ## vector length equals to vocabulary size.

# Define the model
model = Sequential()
model.add(Dense(16, kernel_regularizer=regularizers.l2(0.001),
                          activation='relu', input_shape=(input_size,)))
model.add(Dense(16, kernel_regularizer=regularizers.l2(0.001),
                          activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model using a loss function and an optimizer.
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history_l2 = model.fit(x_train, y_train, epochs=20, batch_size=32, validation_data=(x_dev, y_dev), verbose=0)

# summarize history for accuracy
plt.plot(history_orig.history['loss'])
plt.plot(history_l2.history['loss'])

plt.plot(history_orig.history['val_loss'])
plt.plot(history_l2.history['val_loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train: orig', 'train: l2', 'dev: orig', 'dev: l2'], loc='upper left')
plt.show()

# %% [markdown]
# ### Exercise 6
# - Explore different regularization weigths (e.g. 0.001, 0.01, 0.1). Do you see any difference in the learning curves?
# - You can try __L1 regularization__, or both together.
#
# ```
# # L1 regularization
# regularizers.l1(0.001)
#
# # L1 and L2 regularization at the same time
# regularizers.l1_l2(l1=0.001, l2=0.001)
# ```
#
# -----

# %% [markdown]
# ### 4.3 Adding dropout
# Another popular regularization technique for deep learning is _dropout_. It has been proven to be very successful in many cases, which state-of-the-art of the architecture can be improved around 1-2% of accuracy.
#
# The algorithm is simple: At every training step every unit has a probability $p$ of being dropped out (it will not take into account during the evaluation step, setting it to zero).  In Keras user needs to set a _dropout rate_, which is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.

# %%
from tensorflow.keras.layers import Dropout

input_size = x_train[0].shape[0] ## vector length equals to vocabulary size.

# Define the model
model = Sequential()
model.add(Dense(units=16, activation='relu', input_shape=(input_size,)))
# we add a drop-out layer after the first fully connected layer
model.add(Dropout(0.6))

model.add(Dense(units=16, activation='relu'))
# we add a drop-out layer after the second fully connected layer
model.add(Dropout(0.6))
model.add(Dense(units=1, activation='sigmoid'))

# Compile the model using a loss function and an optimizer.
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# Train the model
history = model.fit(x_train, y_train, epochs=20, batch_size=32, validation_data=(x_dev, y_dev), verbose=0)

# summarize history for accuracy
plt.plot(history_orig.history['loss'])
plt.plot(history.history['loss'])

plt.plot(history_orig.history['val_loss'])
plt.plot(history.history['val_loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train: orig model', 'train: dropout', 'dev: orig model', 'dev: dropout'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_45 (Dense)                │ (None, 16)             │        16,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,305 (63.69 KB)
#  Trainable params: 16,305 (63.69 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Exercise 7
# - Try different dropout rates and decide which one is the best.

# %% [markdown]
# ## Improve your model
# It would be great if you could try improving the model by exploring different hyperparameters. For example,  you can explore the following ones:
# - Learning Rates of the optimizer.
# - Combination of different regularization techniques.
# - Vocabulary size (using larger set of words).
# - Number of hidden layers and size of the layers.
# - Number of training epochs.
